# %%
from scipy.misc import imread
from sklearn.externals import joblib

import random as rand
import numpy as np 
import cv2
import glob
import time

import matplotlib.pyplot as plt
# %matplotlib inline

from helpers import convert, show_images
from featuresourcer import FeatureSourcer

import warnings
warnings.filterwarnings('ignore')

# %%
sourcer_params = {
  'color_model': 'yuv',                # hls, hsv, yuv, ycrcb
  'bounding_box_size': 64,             #
  'number_of_orientations': 11,        # 6 - 12
  'pixels_per_cell': 16,               # 8, 16
  'cells_per_block': 2,                # 1, 2
  'do_transform_sqrt': True
}

# %%
start_frame = imread("datasets/cropped/insect/Bee/Screenshot 2019-03-27 at 17.38.23.png")

sourcer = FeatureSourcer(sourcer_params)

f = sourcer.features(start_frame)
print("feature shape:", f.shape)

rgb_img, a_img, b_img, c_img = sourcer.visualize()
show_images([rgb_img, a_img, b_img, c_img], per_row = 4, per_col = 1, W = 10, H = 2)
# Out:
# feature shape: (763620,)

# %%
start_frame = imread("datasets/full/other/Bee/bef31f68-a867-43e2-9c7b-91902fb777cf_image.jpg")
sourcer = FeatureSourcer(sourcer_params)

f = sourcer.features(start_frame)
print("feature shape:", f.shape)

rgb_img, a_img, b_img, c_img = sourcer.visualize()
show_images([rgb_img, a_img, b_img, c_img], per_row = 4, per_col = 1, W = 10, H = 2)
# Out:
# feature shape: (927828,)
